# %%
import os

# %%
import pandas as pd

# %%
import sqlite3

# %%
os.getcwd()
# Out:
# 'C:\\Users\\EMJOE\\Documents\\Workstation'

# %%
wdPath = "C:/sandbox"

# %%
os.chdir(wdPath)

# %%
os.getcwd()
# Out:
# 'C:\\sandbox'

# %%
df = pd.read_csv("diamonds.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
dbPath = "C:/sandbox/hubway.db"

# %%
conn = sqlite3.connect(dbPath)

# %%
cur = conn.cursor()

# %%
query = "create table diamonds (ID char(15), carat numeric(2,1), cut char(15), color char(5), clarity char(15), depth numeric(3,1), tables numeric(3,1), price char(15), x numeric(3,1), y numeric(3,1), z numeric(3,1));"
#python will not accept any colume name as "table"

# %%
cur.execute(query)

# %%
query3 = "select name from sqlite_master where type = 'table'"
cur.execute(query3)
result = cur.fetchall()
result
# Out:
# [('instructor',), ('daibetes',), ('diamonds',)]

# %%
query2 = "select * from diamonds"
cur.execute(query2)
result2 = cur.fetchall()
result2
# Out:
# []

# %%
sqlTableHead = pd.read_sql_query(query2, conn)
sqlTableHead
# Out:
# Empty DataFrame
# Columns: [ID, carat, cut, color, clarity, depth, tables, price, x, y, z]
# Index: []

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0.23, 'Ideal', ..., 3.95, 3.98, 2.43],
#        [2, 0.21, 'Premium', ..., 3.89, 3.84, 2.31],
#        [3, 0.23, 'Good', ..., 4.05, 4.07, 2.31],
#        ...,
#        [53938, 0.7, 'Very Good', ..., 5.66, 5.68, 3.56],
#        [53939, 0.86, 'Premium', ..., 6.15, 6.12, 3.74],
#        [53940, 0.75, 'Ideal', ..., 5.83, 5.87, 3.64]], dtype=object)

# %%
rows = df.values
for row in rows:
    row = tuple(row)
    query4 = f"insert into diamonds values{row}"
    cur.execute(query4)

# %%
query5 = "select * from diamonds"
cur.execute(query5)
result3 = cur.fetchall()
result3
# Out:
# [('1', 0.23, 'Ideal', 'E', 'SI2', 61.5, 55, '326', 3.95, 3.98, 2.43),
#  ('2', 0.21, 'Premium', 'E', 'SI1', 59.8, 61, '326', 3.89, 3.84, 2.31),
#  ('3', 0.23, 'Good', 'E', 'VS1', 56.9, 65, '327', 4.05, 4.07, 2.31),
#  ('4', 0.29, 'Premium', 'I', 'VS2', 62.4, 58, '334', 4.2, 4.23, 2.63),
#  ('5', 0.31, 'Good', 'J', 'SI2', 63.3, 58, '335', 4.34, 4.35, 2.75),
#  ('6', 0.24, 'Very Good', 'J', 'VVS2', 62.8, 57, '336', 3.94, 3.96, 2.48),
#  ('7', 0.24, 'Very Good', 'I', 'VVS1', 62.3, 57, '336', 3.95, 3.98, 2.47),
#  ('8', 0.26, 'Very Good', 'H', 'SI1', 61.9, 55, '337', 4.07, 4.11, 2.53),
#  ('9', 0.22, 'Fair', 'E', 'VS2', 65.1, 61, '337', 3.87, 3.78, 2.49),
#  ('10', 0.23, 'Very Good', 'H', 'VS1', 59.4, 61, '338', 4, 4.05, 2.39),
#  ('11', 0.3, 'Good', 'J', 'SI1', 64, 55, '339', 4.25, 4.28, 2.73),
#  ('12', 0.23, 'Ideal', 'J', 'VS1', 62.8, 56, '340', 3.93, 3.9, 2.46),
#  ('13', 0.22, 'Premium', 'F', 'SI1', 60.4, 61, '342', 3.88, 3.84, 2.33),
# ...

# %%
sqlDF = pd.read_sql_query(query5, conn)
sqlDF
# Out:
#           ID  carat        cut color clarity  depth  tables price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5    55.0   326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8    61.0   326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9    65.0   327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4    58.0   334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3    58.0   335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...     ...   ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8    57.0  2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1    55.0  2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8    60.0  2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0    58.0  2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2    55.0  2757  5.83  5.87
#
#           z
# 0      2.43
# ...
