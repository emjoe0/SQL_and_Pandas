# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\EMJOE\\Documents\\Workstation'

# %%
path = "C:/sandbox"

# %%
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\sandbox'

# %%
import pandas as pd
import sqlite3

# %%
dbPath = "C:/sandbox/hubway.db"

# %%
conn = sqlite3.connect(dbPath)

# %%
cur = conn.cursor()

# %%
query = "select * from sqlite_master where type = 'table'"
cur.execute(query)
result = cur.fetchall()
result
# Out:
# [('table',
#   'instructor',
#   'instructor',
#   2,
#   'CREATE TABLE instructor(ID char(5), name varchar(20) not null, salary numeric(8,2))')]

# %%
query1 = "select * from instructor"
cur.execute(query1)
result2 = cur.fetchall()
result2
# Out:
# []

# %%
df = pd.read_csv("C:/sandbox/daibetes_clean.csv")
df
# Out:
#       ID  No_Pation  Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...     ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317       1   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534       1   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654       1   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004       1   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054       1   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI  CLASS
# 0    24.0      0
# ...

# %%
query2 = "create table daibetes(ID char(5), No_Pation char(7), Gender char(2), AGE char(3), Urea number(2,1), Cr char(3), HbA1c number(2,1), Chol number(2,1), TG number(2,1), HDL number(2,1), LDL number(2,1), VLDL number(2,1), BMI number(3,1), CLASS char(2))"
cur.execute(query2)
result3 = cur.fetchall()
result3
# Out:
# []

# %%
query = "select * from sqlite_master where type = 'table'"
cur.execute(query)
result = cur.fetchall()
result
# Out:
# [('table',
#   'instructor',
#   'instructor',
#   2,
#   'CREATE TABLE instructor(ID char(5), name varchar(20) not null, salary numeric(8,2))'),
#  ('table',
#   'daibetes',
#   'daibetes',
#   3,
#   'CREATE TABLE daibetes(ID char(5), No_Pation char(7), Gender char(2), AGE char(3), Urea number(2,1), Cr char(3), HbA1c number(2,1), Chol number(2,1), TG number(2,1), HDL number(2,1), LDL number(2,1), VLDL number(2,1), BMI number(3,1), CLASS char(2))')]

# %%
df
# Out:
#       ID  No_Pation  Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...     ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317       1   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534       1   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654       1   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004       1   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054       1   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI  CLASS
# 0    24.0      0
# ...

# %%
rows = df.values
rows
# Out:
# array([[5.0200e+02, 1.7975e+04, 0.0000e+00, ..., 5.0000e-01, 2.4000e+01,
#         0.0000e+00],
#        [7.3500e+02, 3.4221e+04, 1.0000e+00, ..., 6.0000e-01, 2.3000e+01,
#         0.0000e+00],
#        [4.2000e+02, 4.7975e+04, 0.0000e+00, ..., 5.0000e-01, 2.4000e+01,
#         0.0000e+00],
#        ...,
#        [6.6900e+02, 8.7654e+04, 1.0000e+00, ..., 8.1000e+00, 2.7400e+01,
#         1.0000e+00],
#        [9.9000e+01, 2.4004e+04, 1.0000e+00, ..., 1.4000e+01, 4.0500e+01,
#         1.0000e+00],
#        [2.4800e+02, 2.4054e+04, 1.0000e+00, ..., 7.0000e-01, 3.3000e+01,
#         1.0000e+00]])

# %%
for row in rows:
    row = tuple(row)
    query3 = f"insert into daibetes values{row}"
    cur.execute(query3)
    result4 = cur.fetchall()
    result4

# %%
query4 = "select * from daibetes"
cur.execute(query4)
result5 = cur.fetchall()
result5 
#got confused here and thought the for loop code didnt work thinking it only insert the firt row as I didnt call the result with print function
# Out:
# [('502.0',
#   '17975.0',
#   '0.0',
#   '50.0',
#   4.7,
#   '46.0',
#   4.9,
#   4.2,
#   0.9,
#   2.4,
#   1.4,
#   0.5,
#   24,
#   '0.0'),
#  ('735.0',
#   '34221.0',
#   '1.0',
#   '26.0',
#   4.5,
#   '62.0',
#   4.9,
#   3.7,
#   1.4,
#   1.1,
#   2.1,
#   0.6,
#   23,
#   '0.0'),
#  ('420.0',
#   '47975.0',
#   '0.0',
#   '50.0',
#   4.7,
#   '46.0',
#   4.9,
#   4.2,
#   0.9,
#   2.4,
#   1.4,
#   0.5,
#   24,
#   '0.0'),
#  ('680.0',
#   '87656.0',
#   '0.0',
#   '50.0',
#   4.7,
#   '46.0',
#   4.9,
#   4.2,
#   0.9,
#   2.4,
#   1.4,
#   0.5,
#   24,
#   '0.0'),
#  ('504.0',
#   '34223.0',
#   '1.0',
#   '33.0',
#   7.1,
#   '46.0',
#   4.9,
#   4.9,
#   1,
#   0.8,
#   2,
#   0.4,
#   21,
#   '0.0'),
#  ('634.0',
#   '34224.0',
#   '0.0',
#   '45.0',
#   2.3,
#   '24.0',
#   4,
#   2.9,
#   1,
#   1,
#   1.5,
#   0.4,
#   21,
#   '0.0'),
#  ('721.0',
#   '34225.0',
#   '0.0',
#   '50.0',
#   2,
#   '50.0',
#   4,
#   3.6,
#   1.3,
#   0.9,
#   2.1,
#   0.6,
#   24,
# ...

# %%
len(result5)
# Out:
# 999

# %%
query5 = "delete from daibetes where id = 502.0" #I used this code in order to delete the the row I thought was the only row that got inserted into the database
cur.execute(query5)
# result6 = cur.fetchall()

# %%
query4 = "select * from daibetes"
cur.execute(query4)
result5 = cur.fetchall()
print(result5) 
#After deleting the row, I called the daibetes table again (without the print function) to expect an empty table but surprisingly, I saw another row. Then I used the print function to view what is in the table then I noticed that the for loop code work and all rows where inserted into the database.
# Out:
# [('735.0', '34221.0', '1.0', '26.0', 4.5, '62.0', 4.9, 3.7, 1.4, 1.1, 2.1, 0.6, 23, '0.0'), ('420.0', '47975.0', '0.0', '50.0', 4.7, '46.0', 4.9, 4.2, 0.9, 2.4, 1.4, 0.5, 24, '0.0'), ('680.0', '87656.0', '0.0', '50.0', 4.7, '46.0', 4.9, 4.2, 0.9, 2.4, 1.4, 0.5, 24, '0.0'), ('504.0', '34223.0', '1.0', '33.0', 7.1, '46.0', 4.9, 4.9, 1, 0.8, 2, 0.4, 21, '0.0'), ('634.0', '34224.0', '0.0', '45.0', 2.3, '24.0', 4, 2.9, 1, 1, 1.5, 0.4, 21, '0.0'), ('721.0', '34225.0', '0.0', '50.0', 2, '50.0', 4, 3.6, 1.3, 0.9, 2.1, 0.6, 24, '0.0'), ('421.0', '34227.0', '1.0', '48.0', 4.7, '47.0', 4, 2.9, 0.8, 0.9, 1.6, 0.4, 24, '0.0'), ('670.0', '34229.0', '1.0', '43.0', 2.6, '67.0', 4, 3.8, 0.9, 2.4, 3.7, 1, 21, '0.0'), ('759.0', '34230.0', '0.0', '32.0', 3.6, '28.0', 4, 3.8, 2, 2.4, 3.8, 1, 24, '0.0'), ('636.0', '34231.0', '0.0', '31.0', 4.4, '55.0', 4.2, 3.6, 0.7, 1.7, 1.6, 0.3, 23, '0.0'), ('788.0', '34232.0', '0.0', '33.0', 3.3, '53.0', 4, 4, 1.1, 0.9, 2.7, 1, 21, '0.0'), ('82.0', '46815.0', '0.0', '
# ...

# %%
#Adding the deleted row back into the database to avoid shortage of data in the dataframe
query6 = "insert into daibetes values(502, 17975, 0, 50, 4.7, 46, 4.9, 4.2, 0.9, 2.4, 1.4, 0.5, 24.0, 0)"
cur.execute(query6)

# %%
#selecting all colums to confirm the deleted rows was added
query7 = "select * from daibetes"
cur.execute(query7)
result6 = cur.fetchall()
print(result6)
# Out:
# [('735.0', '34221.0', '1.0', '26.0', 4.5, '62.0', 4.9, 3.7, 1.4, 1.1, 2.1, 0.6, 23, '0.0'), ('420.0', '47975.0', '0.0', '50.0', 4.7, '46.0', 4.9, 4.2, 0.9, 2.4, 1.4, 0.5, 24, '0.0'), ('680.0', '87656.0', '0.0', '50.0', 4.7, '46.0', 4.9, 4.2, 0.9, 2.4, 1.4, 0.5, 24, '0.0'), ('504.0', '34223.0', '1.0', '33.0', 7.1, '46.0', 4.9, 4.9, 1, 0.8, 2, 0.4, 21, '0.0'), ('634.0', '34224.0', '0.0', '45.0', 2.3, '24.0', 4, 2.9, 1, 1, 1.5, 0.4, 21, '0.0'), ('721.0', '34225.0', '0.0', '50.0', 2, '50.0', 4, 3.6, 1.3, 0.9, 2.1, 0.6, 24, '0.0'), ('421.0', '34227.0', '1.0', '48.0', 4.7, '47.0', 4, 2.9, 0.8, 0.9, 1.6, 0.4, 24, '0.0'), ('670.0', '34229.0', '1.0', '43.0', 2.6, '67.0', 4, 3.8, 0.9, 2.4, 3.7, 1, 21, '0.0'), ('759.0', '34230.0', '0.0', '32.0', 3.6, '28.0', 4, 3.8, 2, 2.4, 3.8, 1, 24, '0.0'), ('636.0', '34231.0', '0.0', '31.0', 4.4, '55.0', 4.2, 3.6, 0.7, 1.7, 1.6, 0.3, 23, '0.0'), ('788.0', '34232.0', '0.0', '33.0', 3.3, '53.0', 4, 4, 1.1, 0.9, 2.7, 1, 21, '0.0'), ('82.0', '46815.0', '0.0', '
# ...

# %%
len(result6) #using the length function to confirm that the total number of rows in 1000
# Out:
# 1000

# %%
sqlDF = pd.read_sql_query(query7, conn)
sqlDF
# Out:
#         ID No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0    735.0   34221.0    1.0  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 1    420.0   47975.0    0.0  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 2    680.0   87656.0    0.0  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3    504.0   34223.0    1.0  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# 4    634.0   34224.0    0.0  45.0   2.3  24.0    4.0   2.9  1.0  1.0  1.5
# ..     ...       ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 995  671.0  876534.0    1.0  31.0   3.0  60.0   12.3   4.1  2.2  0.7  2.4
# 996  669.0   87654.0    1.0  30.0   7.1  81.0    6.7   4.1  1.1  1.2  2.4
# 997   99.0   24004.0    1.0  38.0   5.8  59.0    6.7   5.3  2.0  1.6  2.9
# 998  248.0   24054.0    1.0  54.0   5.0  67.0    6.9   3.8  1.7  1.1  3.0
# 999    502     17975      0    50   4.7    46    4.9   4.2  0.9  2.4  1.4
#
#      VLDL   BMI CLASS
# 0     0.6  23.0   0.0
# 1     0.5  24.0   0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   int64
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   int64
# dtypes: float64(8), int64(6)
# memory usage: 109.5 KB
